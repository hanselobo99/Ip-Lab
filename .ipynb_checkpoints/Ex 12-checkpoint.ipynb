# %%
# Write a python program using OpenCV library and perform
# Simple thresholding for an image. Demonstrate the following
# Simple thresholding techniques.

# %%
# a. Binary threshold
import cv2
import numpy as np
import matplotlib.pyplot as plt
path = r'/home/hansel/ip/Images/image4.jpg'
img=cv2.imread(path)
img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
ret,thresh1=cv2.threshold(img,120,255,cv2.THRESH_BINARY)
plt.subplot(121),plt.title("Image"),plt.imshow(img,cmap="gray")
plt.subplot(122),plt.title("Binary"),plt.imshow(thresh1,cmap="gray")
# Out:
# (<AxesSubplot:title={'center':'Binary'}>,
#  Text(0.5, 1.0, 'Binary'),
#  <matplotlib.image.AxesImage at 0x7f344c2e98d0>)

# %%
# b. Inverted Binary threshold
import cv2
import numpy as np
import matplotlib.pyplot as plt
path = r'/home/hansel/ip/Images/image4.jpg'
img=cv2.imread(path)
img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
ret,thresh1=cv2.threshold(img,120,255,cv2.THRESH_BINARY_INV)
plt.subplot(121),plt.title("Image"),plt.imshow(img,cmap="gray")
plt.subplot(122),plt.title("Inverted"),plt.imshow(thresh1,cmap="gray")
# Out:
# (<AxesSubplot:title={'center':'Inverted'}>,
#  Text(0.5, 1.0, 'Inverted'),
#  <matplotlib.image.AxesImage at 0x7f344c1a4940>)

# %%
# c. Threshold truncate
import cv2
import numpy as np
import matplotlib.pyplot as plt
path = r'/home/hansel/ip/Images/image4.jpg'
img=cv2.imread(path)
img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
ret,thresh1=cv2.threshold(img,120,255,cv2.THRESH_TRUNC)
plt.subplot(121),plt.title("Image"),plt.imshow(img,cmap="gray")
plt.subplot(122),plt.title("Truncate"),plt.imshow(thresh1,cmap="gray")
# Out:
# (<AxesSubplot:title={'center':'Truncate'}>,
#  Text(0.5, 1.0, 'Truncate'),
#  <matplotlib.image.AxesImage at 0x7f3446f4d390>)

# %%
# d. Threshold to zero
import cv2
import numpy as np
import matplotlib.pyplot as plt
path = r'/home/hansel/ip/Images/image4.jpg'
img=cv2.imread(path)
img=cv2.cvtColor(img,cv2.COLOR_BGR2GRAY)
ret,thresh1=cv2.threshold(img,120,255,cv2.THRESH_TOZERO)
plt.subplot(121),plt.title("Image"),plt.imshow(img,cmap="gray")
plt.subplot(122),plt.title("Zero"),plt.imshow(thresh1,cmap="gray")
# Out:
# (<AxesSubplot:title={'center':'Zero'}>,
#  Text(0.5, 1.0, 'Zero'),
#  <matplotlib.image.AxesImage at 0x7f344c235840>)
